# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle

data = pd.read_csv('../data/dataset.csv')
data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
label_encoder = LabelEncoder()
data['Target'] = label_encoder.fit_transform(data['Target'])

X = data.drop(columns=['Target'])
y = data['Target']

# %% [markdown]
# Let's peform PCA for feature selection

# %%
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

# initiate PCA and classifier with 5 componenets
pca = PCA(n_components=10)


X_pca = pca.fit_transform(X)

# %% [markdown]
# We will now compare the performance of our baseline models trained on original and after PCA data.

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# baseline Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_rf_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_rf_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6971751412429379

# %%
# baseline Gradient Boosting
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="multi:softmax")

xgb_model.fit(X_train, y_train)

y_gb_pred = xgb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_gb_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7005649717514124

# %%
# baseline Logistic Regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(solver='liblinear', random_state=14)
logreg.fit(X_train, y_train)

y_logreg_pred = logreg.predict(X_test)
accuracy = accuracy_score(y_test, y_logreg_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6858757062146893
